# %%
from __future__ import absolute_import, division, print_function

# !pip install tensorflow-gpu==2.0.0-alpha0
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print (device_name)
# Out:
# Requirement already satisfied: tensorflow-gpu==2.0.0-alpha0 in /usr/local/lib/python3.6/dist-packages (2.0.0a0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.16.3)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.2.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (3.7.1)
# Requirement already satisfied: tb-nightly<1.14.0a20190302,>=1.14.0a20190301 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.14.0a20190301)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.33.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.9)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.0.7)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.15.0)
# Requirement already satisfied: tf-estimator-nightly<1.14.0.dev2019030116,>=1.14.0.dev2019030115 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (1.14.0.dev2019030115)
# Requirement already satisfied: google-pasta>=0.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.1.6)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.0-alpha0) (0.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.0-alpha0) (41.0.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (0.15.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tb-nightly<1.14.0a20190302,>=1.14.0a20190301->tensorflow-gpu==2.0.0-alpha0) (3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==2.0.0-alpha0) (2.8.0)
# /device:GPU:0

# %%
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
import pandas as pd
import time
import random
import math

# %%
from google.colab import drive

drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
batch_size = 64
emb_size = 300
hidden_size = 512
lr = 1e-3

# %%
# format of files: each line is "word1|tag1 word2|tag2 ..."
train_path = '/content/drive/My Drive/Colab Notebooks/cs11747/data/tag/train.txt' # train set
dev_path = '/content/drive/My Drive/Colab Notebooks/cs11747/data/tag/dev.txt' # dev set

# %%
def read_data(fname, shuffle=False):
    """
    Read tagged file
    """
    with open(fname, "r") as f:
        word_set = []
        tag_set = []
        for line in f:
            words, tags = [], ['<start>']
            for wt in line.lower().strip().split():
                w, t = wt.split('|')
                words.append(w)
                tags.append(t)
            word_set.append(' '.join(words))
            tags.append('<end>')
            tag_set.append(' '.join(tags))
        if shuffle:
            c = list(zip(word_set, tag_set))
            random.shuffle(c)
            word_set, tag_set = zip(*c)
        return word_set, tag_set

# %%
train_word, train_tag = read_data(train_path, shuffle=True)
dev_word, dev_tag = read_data(dev_path)

print (len(train_word[0].split()))
print (train_tag[0], len(train_tag[0].split()))
print (len(train_word), len(train_tag), len(dev_word), len(dev_tag))
# Out:
# 17
# <start> o i-org i-org o o o o o o i-misc i-misc i-misc o o o o o <end> 19
# 10000 10000 1696 1696

# %%
tokenizer_word = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<unk>') 
tokenizer_word.fit_on_texts(train_word)
train_seq_word = tokenizer_word.texts_to_sequences(train_word)
dev_seq_word = tokenizer_word.texts_to_sequences(dev_word)

# %%
tokenizer_tag = tf.keras.preprocessing.text.Tokenizer(filters='', oov_token='<unk>') 
tokenizer_tag.fit_on_texts(train_tag)
train_seq_tag = tokenizer_tag.texts_to_sequences(train_tag)
dev_seq_tag = tokenizer_tag.texts_to_sequences(dev_tag)

# %%
w2i = tokenizer_word.word_index
t2i = tokenizer_tag.word_index
nwords = len(w2i)
ntags = len(t2i)
print (f'dictionary for words and tags built. {nwords} words and {ntags} tags')
# Out:
# dictionary for words and tags built. 23694 words and 12 tags

# %%
t2i
# Out:
# {'<end>': 5,
#  '<start>': 4,
#  '<unk>': 1,
#  'b-loc': 10,
#  'b-misc': 9,
#  'b-org': 12,
#  'b-per': 11,
#  'i-loc': 6,
#  'i-misc': 7,
#  'i-org': 8,
#  'i-per': 3,
#  'o': 2}

# %%
# dictionary from id to word, used to decode
i2w = {}
for w, i in w2i.items():
    i2w[i] = w
print (i2w[4])
# Out:
# .

# %%
# dictionary from id to tag, used to decode
i2t = {}
for t, i in t2i.items():
    i2t[i] = t
print (i2t[5])
# Out:
# <end>

# %%
def train_gen(batch_size=batch_size):
    i = 0
    while i<len(train_seq_word):
        if i+batch_size < len(train_seq_word):
            batch_word = tf.keras.preprocessing.sequence.pad_sequences(train_seq_word[i:i+batch_size], padding='post')
            batch_tag = tf.keras.preprocessing.sequence.pad_sequences(train_seq_tag[i:i+batch_size], padding='post')
        else:
            batch_word = tf.keras.preprocessing.sequence.pad_sequences(train_seq_word[i:], padding='post')
            batch_tag = tf.keras.preprocessing.sequence.pad_sequences(train_seq_tag[i:], padding='post')
        i += batch_size
        yield batch_word, batch_tag

# %%
def dev_gen(batch_size=batch_size):
    i = 0
    while i<len(dev_seq_word):
        if i+batch_size < len(dev_seq_word):
            batch_word = tf.keras.preprocessing.sequence.pad_sequences(dev_seq_word[i:i+batch_size], padding='post')
            batch_tag = tf.keras.preprocessing.sequence.pad_sequences(dev_seq_tag[i:i+batch_size], padding='post')
        else:
            batch_word = tf.keras.preprocessing.sequence.pad_sequences(dev_seq_word[i:], padding='post')
            batch_tag = tf.keras.preprocessing.sequence.pad_sequences(dev_seq_tag[i:], padding='post')
        i += batch_size
        yield batch_word, batch_tag

# %% [markdown]
# # Build model

# %%
class BiLSTM_CRF(tf.keras.Model):
    def __init__(self, embed_size, hidden_size):
        super(BiLSTM_CRF, self).__init__()
        self.embedding = tf.keras.layers.Embedding(nwords+1, embed_size, trainable=True)
        self.bilstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(hidden_size//2, 
                                       return_sequences=True, 
                                       recurrent_initializer='glorot_uniform'), merge_mode='concat')
        # emission score
        self.fc = tf.keras.layers.Dense(ntags+1)
        
        # Matrix of transition scores.  Entry i,j is the score of transitioning to i from j.
        self.transitions = np.random.randn(ntags+1, ntags+1)
        self.transitions[t2i['<start>'], :] = -10000. # to start forbidden
        self.transitions[:, t2i['<end>']] = -10000. # from end forbidden
        self.transitions[0, :] = -10000. # to pad forbidden
        self.transitions[0, t2i['<end>']] = 0. # except from end to pad
        self.transitions[:, 0] = -10000. # from pad forbidden
        self.transitions = tf.Variable(self.transitions, trainable=True) #[ntags+1(to), ntags+1(from)]]
        
    # normalizer. sum of all possible paths
    def _forward_alg(self, feats, mask): # feats [batch, t, ntags+1], mask [batch, t]
        batch = tf.shape(feats)[0]
        forward = np.full((batch, ntags+1), -10000.)
        forward[:, t2i['<start>']] = 0. #[batch, ntags+1]
        forward = tf.Variable(forward, trainable=False)
        
        steps = tf.shape(feats)[1]
        for step in range(steps):
            feat = feats[:, step, :] #[batch, ntags+1]
            mask_t = mask[:, step+1] #[batch]
            # for sentence that is not finised, need to forward to next step. otherwise remain forward unchanged. controlled by mask.
            forward_next = tf.broadcast_to(tf.expand_dims(forward, axis=1), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            emit = tf.broadcast_to(tf.expand_dims(feat, axis=-1), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            trans = tf.broadcast_to(tf.expand_dims(self.transitions, axis=0), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            emit = tf.cast(emit, tf.float64)
            #print (forward_next, emit, trans)
            next_score = forward_next + emit + trans #[batch, ntags+1(to), ntags+1(from)]
            next_score = tf.math.reduce_logsumexp(next_score, axis=-1) #[batch, ntags+1(to)]
            forward = tf.where(mask_t, next_score, forward) #[batch, ntags+1]
            
        last = forward + self.transitions[t2i['<end>'], :] #[batch, ntags+1]
        alpha = tf.math.reduce_logsumexp(last, axis=-1) #[batch]
        return alpha
    
    # score of the gold path
    def _score_sent(self, feats, tags, mask): #feats:[batch, t, ntags+1], tags:[batch, t], mask:[batch, t]
        batch = tf.shape(feats)[0]
        m = tf.cast(mask, tf.int32)
        length = tf.reduce_sum(m, axis=-1) #[batch] sentence length (including start tag) used to get the last tag (the tag before end)
        score = tf.zeros([batch])
        steps = tf.shape(feats)[1]
        for step in range(steps):
            feat = feats[:, step, :] #[batch, ntags+1]
            from_tag = tags[:, step] #[batch]
            to_tag = tags[:, step+1] #[batch]
            mask_t = mask[:, step+1] #[batch]
            # get transition score
            i = tf.stack([to_tag, from_tag], axis=-1) #[batch, 2]
            trans = tf.gather_nd(self.transitions, i) #[batch] 
            trans = tf.cast(trans, tf.float32)
            # get emit score
            j = tf.range(batch) #[batch]
            j = tf.stack([j, to_tag], axis=-1) #[batch, 2]
            emit = tf.gather_nd(feat, j) #[batch]
            
            # if one sentence is not finised, need to update to next score. otherwise remain score unchanged. controlled by mask.
            next_score = score + trans + emit #[batch]
            score = tf.where(mask_t, next_score, score) #[batch]
            
        # last step only transition score
        k = tf.range(batch) #[batch]
        k = tf.stack([k, tf.math.add(length, -1)], axis=-1) #[batch, 2]
        from_tag = tf.gather_nd(tags, k) #[batch]
        to_tag = tf.fill(tf.shape(from_tag), t2i['<end>']) #[batch]
        i = tf.stack([to_tag, from_tag], axis=-1) #[batch, 2]
        trans = tf.gather_nd(self.transitions, i) #[batch] 
        trans = tf.cast(trans, tf.float32)
        score = score + trans #[batch]
        return score
            
    # negtive log likelihood loss function
    def nll_cost(self, sent, tags): # sent [batch, t], tags [batch, t]
        x = self.embedding(sent) #[batch, t, emb]
        x = self.bilstm(x) #[batch, t, hidden]
        x = self.fc(x) #[batch, t, ntags+1]
        mask = tf.math.logical_not(tf.math.logical_or(tf.math.equal(tags, 0), tf.math.equal(tags, t2i['<end>']))) # padding and end are masked
        alpha = self._forward_alg(x, mask)
        alpha = tf.cast(alpha, tf.float32)
        gold = self._score_sent(x, tags, mask)
        return alpha - gold #[batch]
    
    # viterbi algorithm for decoding
    def _viterbi(self, feats, mask): #feats: [batch, t, ntags+1], mask: [batch, t]
        batch = tf.shape(feats)[0]
        forward = np.full((batch, ntags+1), -10000.)
        forward[:, t2i['<start>']] = 0. #[batch, ntags+1]
        forward = tf.Variable(forward, trainable=False)
        backtrack = []
        
        steps = tf.shape(feats)[1]
        for step in range(steps):
            feat = feats[:, step, :] #[batch, ntags+1]
            mask_t = mask[:, step+1] #[batch]
            # for sentence that is not finised, need to forward to next step. otherwise remain forward unchanged. controlled by mask.
            forward_next = tf.broadcast_to(tf.expand_dims(forward, axis=1), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            emit = tf.broadcast_to(tf.expand_dims(feat, axis=-1), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            emit = tf.cast(emit, tf.float64)
            trans = tf.broadcast_to(tf.expand_dims(self.transitions, axis=0), [batch, ntags+1, ntags+1]) #[batch, ntags+1(to), ntags+1(from)]
            #print (forward_next, emit, trans)
            next_score = forward_next + emit + trans #[batch, ntags+1(to), ntags+1(from)]
            best_tag = tf.argmax(next_score, axis=-1) #[batch, ntags+1(to)]
            backtrack.append(best_tag)
            best_score = tf.reduce_max(next_score, axis=-1) #[batch, ntags+1(to)]
            forward = tf.where(mask_t, best_score, forward) #[batch, ntags+1]
            
        # last step to end token. only transition score
        last = forward + self.transitions[t2i['<end>'], :] #[batch, ntags+1]
        best_last_tag = tf.argmax(last, axis=-1) #[batch]
        best_path_score = tf.reduce_max(last, axis=-1) #[batch]
        
        # back track to decode the best path. skip the masked tags
        t = -2
        best_path = [best_last_tag]
        for back in reversed(backtrack):
            mask_t = mask[:, t] #[batch]
            j = tf.range(batch) #[batch]
            j = tf.cast(j, tf.int64)
            j = tf.stack([j, best_last_tag], axis=-1) #[batch, 2]
            prev_tag = tf.gather_nd(back, j) #[batch]
            # for sentence that is not such long, need to remain the last tag before end. otherwise back to previous tag. controlled by mask.
            best_last_tag = tf.where(mask_t, prev_tag, best_last_tag) #[batch]
            best_path.append(best_last_tag)
            t -= 1
        best_path.reverse() # forward
        path_end = tf.fill([batch], t2i['<end>'])
        path_end = tf.cast(path_end, tf.int64)
        best_path.append(path_end) # add end to match the shape of mask
        best_path = tf.stack(best_path, axis=-1) #[batch, t] from start to end
        best_path = tf.where(mask, best_path, tf.cast(mask, tf.int64)) #[batch ,t] mask tags beyond sentence length. end is also masked
        return best_path_score, best_path
        
    # sequence tagging
    def call(self, x): # x:[batch, t]
        mask = tf.math.logical_not(tf.math.equal(x, 0)) # [batch, t]
        batch = tf.shape(x)[0]
        start_mask = tf.fill([batch, 1], True) #[batch, 1]
        end_mask = tf.fill([batch, 1], False) #[batch, 1]
        mask = tf.concat([start_mask, mask, end_mask], axis=-1) #[batch, t] padding and end are masked
        
        x = self.embedding(x) #[batch, t, emb]
        x = self.bilstm(x) #[batch, t, hidden]
        x = self.fc(x) #[batch, t, ntags+1]
        
        score, path = self._viterbi(x, mask)
        return score, path

# %%
model = BiLSTM_CRF(emb_size, hidden_size)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0514 02:17:12.412975 140013846337408 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f56edeba400>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# W0514 02:17:12.422863 140013846337408 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f56edebacc0>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %%
def train_step(sent, tag): 
    with tf.GradientTape() as tape:
        batch_loss = model.nll_cost(sent, tag)
        loss = tf.reduce_mean(batch_loss)

    variables = model.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))
  
    return loss

# %%
def eval_step(sent, tag):
    batch_loss = model.nll_cost(sent, tag)
    loss = tf.reduce_mean(batch_loss)
  
    return loss

# %%
optimizer = tf.keras.optimizers.Adam()

# %%
EPOCHS = 10

for epoch in range(EPOCHS):
    start = time.time()
    print ('Epoch {} start ...... '.format(epoch + 1))
    total_loss = 0
    batch = 0
    for sent, tag in train_gen():
        batch_loss = train_step(sent, tag)
        total_loss += batch_loss
        batch += 1

        if batch % 20 == 0:
            print('  ---- Batch {} Loss {:.4f}'.format(batch, batch_loss))
    
    # Evaluate on dev set
    dev_loss = 0
    batch_eval = 0
    for sent, tag in dev_gen():
        batch_loss = eval_step(sent, tag)
        dev_loss += batch_loss
        batch_eval += 1

    print('Epoch {} finished in {} seconds. Training loss {:.4f}. Evaluation loss {:.4f}.'.format(epoch + 1, time.time() - start, total_loss / batch, dev_loss / batch_eval))
# Out:
# Epoch 1 start ......
#   ---- Batch 20 Loss 15.4017
#   ---- Batch 40 Loss 13.1362
#   ---- Batch 60 Loss 9.6502
#   ---- Batch 80 Loss 10.4112
#   ---- Batch 100 Loss 6.1642
#   ---- Batch 120 Loss 6.6460
#   ---- Batch 140 Loss 6.2544
# Epoch 1 finished in 81.28769636154175 seconds. Training loss 11.3478. Evaluation loss 9.8316.
# Epoch 2 start ......
#   ---- Batch 20 Loss 5.1833
#   ---- Batch 40 Loss 4.0594
#   ---- Batch 60 Loss 4.0787
#   ---- Batch 80 Loss 4.9632
#   ---- Batch 100 Loss 2.8861
#   ---- Batch 120 Loss 3.3668
#   ---- Batch 140 Loss 3.0349
# Epoch 2 finished in 77.57497715950012 seconds. Training loss 4.1359. Evaluation loss 9.3675.
# Epoch 3 start ......
#   ---- Batch 20 Loss 2.8783
#   ---- Batch 40 Loss 2.1395
#   ---- Batch 60 Loss 2.4061
#   ---- Batch 80 Loss 3.2640
#   ---- Batch 100 Loss 1.9142
#   ---- Batch 120 Loss 2.0513
#   ---- Batch 140 Loss 1.8487
# Epoch 3 finished in 77.2682056427002 seconds. Training loss 2.3775. Evaluation loss 9.8468.
# Epoch 4 start ......
#   ---- Batch 20 Loss 1.8800
#   ---- Batch 40 Loss 1.4437
#   ---- Batch 60 Loss 1.9430
#   ---- Batch 80 Loss 2.1481
#   ---- Batch 100 Loss 1.4794
#   ---- Batch 120 Loss 1.8223
#   ---- Batch 140 Loss 1.3554
# Epoch 4 finished in 78.56009984016418 seconds. Training loss 1.6816. Evaluation loss 11.4288.
# Epoch 5 start ......
#   ---- Batch 20 Loss 1.5064
#   ---- Batch 40 Loss 1.5146
#   ---- Batch 60 Loss 1.5760
#   ---- Batch 80 Loss 1.8422
#   ---- Batch 100 Loss 0.9877
#   ---- Batch 120 Loss 1.6495
#   ---- Batch 140 Loss 1.0927
# Epoch 5 finished in 77.92790389060974 seconds. Training loss 1.4017. Evaluation loss 11.2365.
# Epoch 6 start ......
#   ---- Batch 20 Loss 1.4417
#   ---- Batch 40 Loss 0.7947
#   ---- Batch 60 Loss 1.0794
#   ---- Batch 80 Loss 1.6791
#   ---- Batch 100 Loss 0.8102
#   ---- Batch 120 Loss 0.9838
#   ---- Batch 140 Loss 0.8126
# Epoch 6 finished in 76.80888938903809 seconds. Training loss 1.0059. Evaluation loss 13.4037.
# Epoch 7 start ......
#   ---- Batch 20 Loss 0.9750
#   ---- Batch 40 Loss 0.5437
#   ---- Batch 60 Loss 0.5896
#   ---- Batch 80 Loss 1.0904
#   ---- Batch 100 Loss 0.7663
#   ---- Batch 120 Loss 0.9069
#   ---- Batch 140 Loss 0.6665
# Epoch 7 finished in 76.84290909767151 seconds. Training loss 0.8053. Evaluation loss 14.0950.
# Epoch 8 start ......
#   ---- Batch 20 Loss 0.6278
#   ---- Batch 40 Loss 0.6908
#   ---- Batch 60 Loss 0.4928
#   ---- Batch 80 Loss 0.8936
#   ---- Batch 100 Loss 0.7029
#   ---- Batch 120 Loss 0.9745
#   ---- Batch 140 Loss 0.5937
# Epoch 8 finished in 77.60933756828308 seconds. Training loss 0.7763. Evaluation loss 13.9639.
# Epoch 9 start ......
#   ---- Batch 20 Loss 0.6006
#   ---- Batch 40 Loss 0.7387
#   ---- Batch 60 Loss 0.5248
#   ---- Batch 80 Loss 0.8641
#   ---- Batch 100 Loss 0.4040
#   ---- Batch 120 Loss 0.8458
#   ---- Batch 140 Loss 0.4199
# Epoch 9 finished in 77.9607846736908 seconds. Training loss 0.5758. Evaluation loss 15.4720.
# Epoch 10 start ......
#   ---- Batch 20 Loss 0.4481
#   ---- Batch 40 Loss 0.3306
#   ---- Batch 60 Loss 0.4352
#   ---- Batch 80 Loss 0.6742
#   ---- Batch 100 Loss 0.3324
#   ---- Batch 120 Loss 0.4327
#   ---- Batch 140 Loss 0.2512
# Epoch 10 finished in 76.60178732872009 seconds. Training loss 0.4091. Evaluation loss 15.9633.

# %%
def decode_sent(sent):
    words = []
    for w in sent:
        if w == 0:
            break
        words.append(i2w[w])
    return ' '.join(words)

# %%
def decode_tag(tag):
    tags = []
    for t in tag:
        if t == t2i['<start>']:
            continue
        if t == 0 or t == t2i['<end>']:
            break
        tags.append(i2t[t])
    return ' '.join(tags)

# %%
def ner_tag():
    for sent, tag in dev_gen():
        score, path = model(sent)
        for i, s in enumerate(score): 
            print ('====================================================')
            print (f'sentence is: {decode_sent(sent[i])}')
            print (f'gold tag is: {decode_tag(tag[i])}')
            print (f'prediction : {decode_tag(path[i].numpy())}')
            print (f'score is: {s}')

# %%
ner_tag()
# Out:
# ====================================================
# sentence is: <unk> is the tenth album from japanese punk techno band the mad capsule markets .
# gold tag is: i-misc o o o o o i-misc o o o i-org i-org i-org i-org o
# prediction : o o o o o o i-misc o o o o i-misc i-misc o o
# score is: 127.84922551770306
# ====================================================
# sentence is: this album proved to be more commercial and more <unk> than <unk> , with heavily synthesized songs like introduction <unk> and come .
# gold tag is: o o o o o o o o o o o i-misc o o o o o o i-misc i-misc o i-misc o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o
# score is: 222.82548467039985
# ====================================================
# sentence is: founding member <unk> minoru played <unk> on good day , and <unk> cover of a song by uk post punk industrial band killing joke .
# gold tag is: o o i-per i-per o o o i-misc i-misc o o i-misc o o o o o i-loc o o o o i-org i-org o
# prediction : o o o i-per o i-per o i-org i-org o o o o o o o o i-misc i-misc i-misc o o o o o
# score is: 194.27585582304653
# ====================================================
# sentence is: <unk> can of this had a different meaning , and most people did n't understand what the song was about .
# gold tag is: i-misc i-misc i-misc i-misc o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o
# score is: 234.87360378060598
# ====================================================
# sentence is: it was later explained that the song was about cannabis ( ' can of this ' <unk> like cannabis when said faster ) it is uncertain if they were told to change the <unk> like they did on <unk> and humanity .
# gold tag is: o o o o o o o o o i-misc o o o o o o o o i-misc o o o o o o o o o o o o o o o o o o o i-misc o i-misc o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 456.11735486485094
# ====================================================
# sentence is: uk edition came with the <unk> video , and most of the tracks were <unk> .
# gold tag is: i-loc o o o o i-misc o o o o o o o o o o
# prediction : i-loc o o o o o o o o o o o o o o o
# score is: 159.71385373413864
# ====================================================
# sentence is: the <unk> was formed at camp howe , near pittsburgh , on september 1 , 1862 .
# gold tag is: o i-org o o o i-loc i-loc o o i-loc o o o o o o o
# prediction : o o o o o o i-per o o i-loc o o o o o o o
# score is: 160.26937848425226
# ====================================================
# sentence is: frederick h. <unk> was the first colonel .
# gold tag is: i-per i-per i-per o o o o o
# prediction : i-per i-per i-per o o o o o
# score is: 98.55743031694946
# ====================================================
# sentence is: after <unk> the dead on the field of second battle of bull run , the regiment was attached to howe 's brigade of <unk> 's division of the iv corps of the army of the potomac where it replaced de <unk> 's <unk> new york , <unk> lafayette regiment on september 11 , 1862 .
# gold tag is: o o o o o o o o i-misc i-misc i-misc i-misc i-misc o o o o o o i-org i-org i-org o i-org i-org i-org o o i-org i-org o o i-org i-org i-org i-org o o o i-org i-org i-org i-org i-org i-org o i-org i-org o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o i-per o o o o o o o o i-org i-org o o i-org i-org i-org i-org o o o i-org i-org o i-org i-org i-org o i-per i-per o o o o o o o
# score is: 460.93801011851133
# ====================================================
# sentence is: the composition of this brigade remained unchanged from this point until the war 's end and included the <unk> <unk> , <unk> <unk> , <unk> <unk> and the <unk> <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o o i-org i-org o i-org i-org o i-org i-org o o i-org i-org o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 273.87471221669693
# ====================================================
# sentence is: during this time <unk> 's division was detached from the army and was occupied with guarding the <unk> on the potomac .
# gold tag is: o o o i-org i-org i-org o o o o i-org o o o o o o o o o i-loc o
# prediction : o o o o o o o o o o o o o o o o o o o o i-loc o
# score is: 216.2394735633111
# ====================================================
# sentence is: the <unk> along with its brigade and division spent the next week marching from <unk> to sandy hook , maryland from where on september 17 , 1862 , it was forced marched to the battle of antietam where it was placed in line of battle but did not see any significant combat .
# gold tag is: o i-org o o o o o o o o o o o o i-loc o i-loc i-loc o i-loc o o o o o o o o o o o o o o i-misc i-misc i-misc o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o i-loc o o o o o o o o o o o o o o i-loc i-loc i-loc o o o o o o o i-loc o o o o o o o o
# score is: 570.4087498143739
# ====================================================
# sentence is: the next day , the regiment pursued the confederate army and fought in a <unk> at <unk> .
# gold tag is: o o o o o o o o i-org o o o o o o o i-loc o
# prediction : o o o o o o o o o o o o o o o o o o
# score is: 163.79411461258692
# ====================================================
# sentence is: the <unk> was transferred in october 1862 to the vi corps .
# gold tag is: o i-org o o o o o o o i-org i-org o
# prediction : o o o o o o o o o i-misc o o
# score is: 106.6158565852714
# ====================================================
# sentence is: in the battle of fredericksburg , it suffered minor casualties from artillery fire , but did n't get a chance to fight .
# gold tag is: o o i-misc i-misc i-misc o o o o o o o o o o o o o o o o o o
# prediction : o o i-loc i-loc i-loc o o o o o o o o o o o o o o o o o o
# score is: 269.08439475657144
# ====================================================
# sentence is: five months later , however , it did participate in the 2nd battle of fredericksburg .
# gold tag is: o o o o o o o o o o o i-misc i-misc i-misc i-misc o
# prediction : o o o o o o o o o o o o o o i-loc o
# score is: 177.0122817644434
# ====================================================
# sentence is: at the battle of gettysburg in july , it helped defend the left <unk> of the union army .
# gold tag is: o o i-misc i-misc i-misc o o o o o o o o o o o i-org o o
# prediction : o o i-loc i-loc i-loc o o o o o o o o o o o i-org i-org o
# score is: 172.2414738262485
# ====================================================
# sentence is: throughout the spring and into early summer of 1864 , the <unk> fought in grant 's overland campaign and the early stages of the siege of petersburg .
# gold tag is: o o o o o o o o o o o i-org o o i-misc i-misc i-misc i-misc o o o o o o i-misc i-misc i-misc o
# prediction : o o o o o o o o o o o o o o i-per o i-misc o o o o o o o i-misc i-misc i-misc o
# score is: 265.20644477015486
# ====================================================
# sentence is: in july , it was transferred to washington , d.c. with the rest of the vi corps to defeat lt. <unk> <unk> early 's attack on the city .
# gold tag is: o o o o o o o i-loc i-loc i-loc o o o o o i-org i-org o o i-per i-per i-per i-per o o o o o o
# prediction : o o o o o o o i-loc o i-loc o o o o o i-loc o o o o o o o o o o o o o
# score is: 271.6874248193773
# ====================================================
# sentence is: then they fought under philip sheridan in the valley to ensure that no more confederate armies would invade again .
# gold tag is: o o o o i-per i-per o o i-loc o o o o o i-org o o o o o
# prediction : o o o o i-per i-per o o o o o o o o o o o o o o
# score is: 213.07347775468028
# ====================================================
# sentence is: ( see the article on the campaign ) .
# gold tag is: o o o o o o o o o
# prediction : o o i-misc i-misc i-misc i-misc o o o
# score is: 75.73436407961049
# ====================================================
# sentence is: by december 1864 , they were back in the siege lines of petersburg .
# gold tag is: o o o o o o o o o o o o i-loc o
# prediction : o o o o o o o o o i-misc o o i-misc o
# score is: 139.15021912488282
# ====================================================
# sentence is: the <unk> supported sheridan in the appomattox campaign and fought in the battle of <unk> 's creek .
# gold tag is: o i-org o i-per o o i-misc i-misc o o o o i-misc i-misc i-misc i-misc i-misc o
# prediction : o o o i-per o o i-misc i-misc o o o o o o i-loc o o o
# score is: 153.73412458353067
# ====================================================
# sentence is: after the surrender at appomattox <unk> , it was ordered to the north carolina border to support william t. sherman , but the confederate surrender there made further support <unk> .
# gold tag is: o o o o i-loc i-loc o o o o o o i-loc i-loc o o o i-per i-per i-per o o o i-org o o o o o o o
# prediction : o o i-misc i-misc i-misc i-misc o o o o o o i-loc i-loc i-per o o i-per i-per i-per o o o i-misc i-misc o o o o o o
# score is: 303.7098071377594
# ====================================================
# sentence is: the regiment was mustered out june 21 , 1865 .
# gold tag is: o o o o o o o o o o
# prediction : o o o o o o o o o o
# score is: 112.34091062586019
# ====================================================
# sentence is: the 1896 atlantic city rail crash occurred shortly after <unk> <unk> on july 30 , 1896 at a crossing just west of atlantic city , new jersey , crushing five loaded passenger coaches , killing 50 and seriously <unk> approximately 60 .
# gold tag is: o o i-loc i-loc o o o o o o o o o o o o o o o o o o i-loc i-loc o i-loc i-loc o o o o o o o o o o o o o o o
# prediction : o o i-loc o o o o o o i-misc i-misc o o o o o o o o o o o i-loc o o i-loc i-loc o o o o o o o o o o o o o o o
# score is: 395.5752678510449
# ====================================================
# sentence is: a train consisting of seven cars left atlantic city over the west jersey railroad <unk> a special <unk> of red men and their friends from <unk> and salem , new jersey , and had reached the crossing of the reading railroad when it was struck by the <unk> down express train from philadelphia .
# gold tag is: o o o o o o o i-loc i-loc o o i-loc i-loc i-loc o o o o o i-misc i-misc o o o o i-loc o i-loc o i-loc i-loc o o o o o o o o i-loc i-loc o o o o o o o o o o o i-loc o
# prediction : o o o o o o o i-loc o o o i-loc i-loc i-org o o o o o o o o o o o o o i-loc o i-loc i-loc o o o o o o o o o i-org o o o o o o o o o o o i-loc o
# score is: 523.6523412959963
# ====================================================
# sentence is: two cars were demolished and the two following cars were <unk> .
# gold tag is: o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o
# score is: 119.24143400794837
# ====================================================
# sentence is: the engine of the reading train was <unk> , the engineer killed , and the <unk> <unk> injured .
# gold tag is: o o o o i-loc o o o o o o o o o o o o o o
# prediction : o o o o o i-misc o o o o o o o o o o o o o
# score is: 160.65297534980326
# ====================================================
# sentence is: the car behind it was <unk> from the track and many of its <unk> were killed or injured .
# gold tag is: o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o
# score is: 201.20987558551425
# ====================================================
# sentence is: in 1896 , leaving atlantic city , the tracks of the west jersey road ran parallel to those of the camden and atlantic until they crossed the <unk> , when they switched off to the south , crossing the reading road at an oblique angle .
# gold tag is: o o o o i-loc i-loc o o o o o i-loc i-loc i-loc o o o o o o i-loc o i-loc o o o o o o o o o o o o o o o o i-loc i-loc o o o o o
# prediction : o o o o i-loc o o o o o o i-loc i-loc i-loc o o o o o o i-loc o i-loc o o o o o o o o o o o o o o o o o o o o o o o
# score is: 466.5741352510844
# ====================================================
# sentence is: john <unk> , the engineer of the west jersey train , saw the reading train <unk> the crossing at a swift speed , but as the signals were open for him to proceed on his way , he continued .
# gold tag is: i-per i-per o o o o o i-loc i-loc o o o o i-loc o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : i-per i-per o o o o o i-loc i-loc o o o o o i-misc i-misc o o o o i-per o o o o o o o o o o o o o o o o o o o
# score is: 389.8389770862529
# ====================================================
# sentence is: his engine had barely cleared the crossing when the <unk> of the reading train , which left philadelphia at <unk> <unk> , struck the first car full in the centre , throwing it far off the track in a nearby <unk> , and completely <unk> it .
# gold tag is: o o o o o o o o o o o o i-loc o o o o i-loc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o i-misc o o o i-loc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 491.29839082552706
# ====================================================
# sentence is: the second car of the west jersey train was also carried into the <unk> , the third and fourth cars being <unk> .
# gold tag is: o o o o o i-loc i-loc o o o o o o o o o o o o o o o o
# prediction : o o o o o i-loc i-loc o o o o o o o o o o o o o o o o
# score is: 211.9075415255248
# ====================================================
# sentence is: the engine of the reading train was <unk> to the other side of the track , carrying with it the first coach .
# gold tag is: o o o o i-loc o o o o o o o o o o o o o o o o o o
# prediction : o o o o o i-misc o o o o o o o o o o o o o o o o o
# score is: 204.93623131960706
# ====================================================
# sentence is: a few minutes after the <unk> , the <unk> of the reading <unk> exploded , <unk> several to death and casting <unk> <unk> over many of the injured passengers .
# gold tag is: o o o o o o o o o o o i-loc o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o i-misc i-misc o o o o o o o o o o o o o o o o
# score is: 286.5672520515782
# ====================================================
# sentence is: as soon as the news reached atlantic city it spread rapidly , and thousands of people flocked to the scene .
# gold tag is: o o o o o o i-loc i-loc o o o o o o o o o o o o o
# prediction : o o o o o o i-loc o o o o o o o o o o o o o o
# score is: 227.60922122304365
# ====================================================
# sentence is: the road leading to the <unk> was a constant scene of <unk> <unk> , <unk> , bicycles , and all kinds of vehicles , while thousands of pedestrians hurried along the path to <unk> what assistance they could or to satisfy their curiosity .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 492.266432715094
# ====================================================
# sentence is: darkness fell quickly , and the work of rescuing the injured and recovering the bodies of the dead was carried out under the <unk> of huge <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 273.6824722800164
# ====================================================
# sentence is: as <unk> watched through the night , the <unk> and burned bodies of the dead were carried from the <unk> which trapped them and laid side by side on the gravel bank near the track , with no other covering than the few newspapers gathered from the passengers .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o i-misc o o o o o o o o o o o o o o o o o o o o o o i-org o o o o o i-misc o o o o o o o o o o o
# score is: 438.6064135343968
# ====================================================
# sentence is: the wounded were quickly gathered together and carried by train and wagon to the atlantic city hospital , where six of them died shortly after their arrival .
# gold tag is: o o o o o o o o o o o o o o i-org i-org i-org o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o i-loc i-loc i-org o o o o o o o o o o o
# score is: 311.92370603970545
# ====================================================
# sentence is: two others died within a day , with 42 having been killed at the <unk> scene .
# gold tag is: o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o
# score is: 190.38911585432024
# ====================================================
# sentence is: the old <unk> house at the foot of mississippi avenue was converted into a <unk> , and the dead were taken there .
# gold tag is: o o i-loc i-loc o o o o i-loc i-loc o o o o o o o o o o o o o
# prediction : o o i-misc i-misc o o o o i-loc i-loc o o o o o o o o o o o o o
# score is: 211.00502146770228
# ====================================================
# sentence is: during the first night after the crash , the streets in the vicinity of the <unk> house and the city hospital , as well as the road leading to the scene of the accident , were packed with people anxious to learn the latest news .
# gold tag is: o o o o o o o o o o o o o o o i-loc i-loc o o i-org i-org o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o i-misc i-misc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 458.2696892351223
# ====================================================
# sentence is: the <unk> and salem <unk> who escaped injury were brought back to atlantic city and sent home on a special train several hours later in the evening .
# gold tag is: o i-loc o i-loc o o o o o o o o i-loc i-loc o o o o o o o o o o o o o o
# prediction : o o o i-loc o o o o o o o o i-loc o o o o o o o o o o o o o o o
# score is: 296.15301503575665
# ====================================================
# sentence is: james w. <unk> , secretary of the new jersey department of public safety , immediately upon learning of the extent of the accident , <unk> for the philadelphia medical emergency corps , fifteen of whom responded , and hurried to atlantic city on a special train which left philadelphia at <unk> <unk> .
# gold tag is: i-per i-per i-per o o o o i-org i-org i-org i-org i-org i-org o o o o o o o o o o o o o o i-org i-org i-org i-org o o o o o o o o o i-loc i-loc o o o o o o i-loc o o o o
# prediction : i-per i-per i-per o o o o i-loc i-loc i-org i-org i-org o o o o o o o o o o o o o o o i-loc i-loc o o o o o o o o o o o i-loc o o o o o o o i-loc o o o o
# score is: 526.33387482343
# ====================================================
# sentence is: these surgeons <unk> aided atlantic city 's volunteer corps , which was composed of almost every physician then living in the city .
# gold tag is: o o o o i-loc i-loc o o o o o o o o o o o o o o o o o
# prediction : o o o o i-loc o o o o o o o o o o o o o o o o o o
# score is: 249.8837081995685
# ====================================================
# sentence is: many of the injured were taken to hotels , as the city hospitals soon became <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o
# score is: 179.924624010143
# ====================================================
# sentence is: about thirty of the wounded had their injuries dressed and were able to proceed on their way .
# gold tag is: o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o
# score is: 225.6525693168716
# ====================================================
# sentence is: the wife of edward <unk> , the reading engineer who died while on the job , and was found with one hand on the <unk> and the other on the brake , when informed of the accident and of her husband 's death , was unable to <unk> the shock , and fell to the floor dead .
# gold tag is: o o o i-per i-per o o i-loc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o i-per i-per o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 588.7130390855069
# ====================================================
# sentence is: county <unk> william <unk> , immediately upon hearing of the accident , went to the scene .
# gold tag is: o o i-per i-per o o o o o o o o o o o o o
# prediction : i-loc i-loc i-per i-per o o o o o o o o o o o o o
# score is: 187.31347139644524
# ====================================================
# sentence is: he went directly into the block tower and questioned operator george f. <unk> <unk> told him that he thought the <unk> train had time to cross the tracks of the reading before the express got there and he set the " clear " signal for the west jersey train .
# gold tag is: o o o o o o o o o o i-per i-per i-per i-per o o o o o o o o o o o o o o o o i-loc o o o o o o o o o o o o o o o i-loc i-loc o o
# prediction : o o o o o o o o o o i-per i-per i-per o o o o o o o o o o o o o o o o o o o o i-misc o o o o o o o o o o o o i-org i-loc o o
# score is: 499.5185594766818
# ====================================================
# sentence is: ( the <unk> system worked as follows : the <unk> block system was used .
# gold tag is: o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o
# score is: 159.80957230583496
# ====================================================
# sentence is: there were three <unk> with <unk> controlled by the tower on the reading tracks and two on the west jersey .
# gold tag is: o o o o o o o o o o o o o o o o o o i-loc i-loc o
# prediction : o o o o o o o o o o o o o o o o o o i-loc i-loc o
# score is: 187.32646232297154
# ====================================================
# sentence is: the pole <unk> from the tower on the reading tracks was distant about 2,000 yards .
# gold tag is: o o o o o o o o i-loc o o o o o o o
# prediction : o i-loc i-loc o o i-loc o o o o o o o o o o
# score is: 147.81642814860584
# ====================================================
# sentence is: the other two were much closer .
# gold tag is: o o o o o o o
# prediction : o o o o o o o
# score is: 70.82476212175105
# ====================================================
# sentence is: when the operator set the " clear " signal on the pennsylvania track , this would <unk> set the " danger " signal on the reading track , and vice versa . )
# gold tag is: o o o o o o o o o o o i-loc o o o o o o o o o o o o o i-loc o o o o o o o
# prediction : o o o o o o o o o o o i-org o o o o o o o o o o o o o o o o o o o o o
# score is: 329.8454718343672
# ====================================================
# sentence is: before <unk> could make a further explanation to the <unk> he received an order from the railroad officials to say nothing .
# gold tag is: o i-per o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o
# score is: 263.95467179851624
# ====================================================
# sentence is: he obeyed , and made no further explanation .
# gold tag is: o o o o o o o o o
# prediction : o o o o o o o o o
# score is: 101.29400703666087
# ====================================================
# sentence is: <unk> an investigation , <unk> was put under arrest by the <unk> , but was released on <unk> bond .
# gold tag is: o o o o i-per o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o
# score is: 201.7475414084477
# ====================================================
# sentence is: a jury was <unk> the following day .
# gold tag is: o o o o o o o o
# prediction : o o o o o o o o
# score is: 69.5373876042609
# ====================================================
# sentence is: testimony on august 4 appeared to <unk> the dead reading railroad express engineer , edward <unk> .
# gold tag is: o o o o o o o o o i-loc i-loc o o o i-per i-per o
# prediction : o o o o o o o o o o o o o o i-per i-per o
# score is: 139.84441669106187
# ====================================================
# sentence is: his action in running at a speed of <unk> miles an hour past a danger signal seemed inexplicable to those present at the inquest .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 280.73965250935146
# ====================================================
# sentence is: his reputation was that of an experienced engineer and a man of exceptionally high moral character , and not of a reckless or careless <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 292.10097727546116
# ====================================================
# sentence is: only two weeks previous to the accident his train was signalled to stop at that very crossing , and he promptly brought his train under control .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 305.8750661139891
# ====================================================
# sentence is: the <unk> 's jury returned <unk> on august 7 .
# gold tag is: o o o o o o o o o o
# prediction : o i-misc i-misc i-misc o o o o o o
# score is: 79.20967428939846
# ====================================================
# sentence is: six <unk> merely stated the manner of the passengers ' deaths .
# gold tag is: o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o
# score is: 124.50177779800269
# ====================================================
# sentence is: three found that " engineer edward d .
# gold tag is: o o o o o i-per i-per o
# prediction : o o o o o i-per o o
# score is: 76.30554124512436
# ====================================================
# sentence is: <unk> of the atlantic city railroad failed for have his engine under proper control on <unk> [ the ] crossing , and that tower man george f. <unk> , in giving the <unk> train of the west jersey railroad the right of way over a fast express used bad <unk> .. [ and ] that engineer john <unk> of said <unk> train <unk> in not exercising greater care on crossing ahead of said fast express . "
# gold tag is: i-per o o i-loc i-loc i-loc o o o o o o o o o o o o o o o o o o o i-per i-per i-per o o o o o o o o i-loc i-loc i-loc o o o o o o o o o o o o o o o o o i-per i-per o o o o o o o o o o o o o o o o o o o
# prediction : o o o i-loc o i-org o o o o o o o o o o o o o o o o o i-loc o i-per i-per o o o o o o o o o i-org i-org i-org o o o o o o o o o o o o o o o o o i-per o o o o o o o o o o o o o o o o o o o o
# score is: 744.2925852056723
# ====================================================
# sentence is: three others found that " the cause of the <unk> was the failure of edward <unk> , engineer of train no. 23 , to give <unk> in time to the <unk> signals and crossing under the <unk> .. the tower man , george f. <unk> , may have used poor judgment in his estimate of the distance away of the atlantic city railroad train when he gave the white boards to the west jersey and <unk> <unk> train no . 700 . "
# gold tag is: o o o o o o o o o o o o o o i-per i-per o o o o o o o o o o o o o o o o o o o o o o o o o o i-per i-per i-per o o o o o o o o o o o o o o o i-loc i-loc i-loc o o o o o o o o o i-loc i-loc o i-loc o o o o o o o
# prediction : o o o o o o o o o o o o o o i-per i-per o o o o o o o o o o o o o o o o o o o o o o o i-misc o o i-per i-per o o o o o o o o o o o o o o o o i-org i-org i-org o o o o o o o o o i-loc i-loc o o i-misc o o o o o o
# score is: 778.4016465278346
# ====================================================
# sentence is: the 2007 bowling green <unk> football team represented bowling green state university in the 2007 <unk> football season .
# gold tag is: o o i-org i-org i-org o o o i-org i-org i-org i-org o o o i-org o o o
# prediction : o o o i-per o o o o o i-per o o o o o o o o o
# score is: 168.73531813259152
# ====================================================
# sentence is: the team was coached by <unk> <unk> and played their home games in <unk> <unk> stadium in bowling green , ohio .
# gold tag is: o o o o o i-per i-per o o o o o o i-loc i-loc i-loc o i-loc i-loc o i-loc o
# prediction : o o o o o o o o o o o o o o o o o o o o i-loc o
# score is: 190.92470739471673
# ====================================================
# sentence is: it was the <unk> season of play for the <unk> .
# gold tag is: o o o o o o o o o i-org o
# prediction : o o o o o o o o o o o
# score is: 104.54111116253873
# ====================================================
# sentence is: bowling green finished the season <unk> overall and has finished <unk> in the mac east .
# gold tag is: i-org i-org o o o o o o o o o o o i-org i-org o
# prediction : o o o o o o o o o o o o o i-org i-org o
# score is: 162.9105389809324
# ====================================================
# sentence is: they participated in the <unk> bowl , losing to <unk> <unk> .
# gold tag is: o o o o i-misc i-misc o o o i-org o o
# prediction : o o o o i-misc i-misc o o o o o o
# score is: 112.58577993790357
# ====================================================
# sentence is: bowling green was picked to finish fifth in the mac east division by the mac news media association .
# gold tag is: i-org i-org o o o o o o o i-org i-org i-org o o i-org i-org i-org i-org o
# prediction : o o o o o o o o o i-org o o o o i-org i-org i-org i-org o
# score is: 182.62284897238789
# ====================================================
# sentence is: three <unk> , senior <unk> <unk> and <unk> <unk> <unk> and corey <unk> , garnered <unk> honors by being named to <unk> <unk> teams .
# gold tag is: o i-org o o i-per i-per o o i-per i-per o i-per i-per o o o o o o o o i-org o o o
# prediction : o o o o o o o o o o o i-per o o o o o o o o o o o o o
# score is: 198.22376498390938
# ====================================================
# sentence is: the 2007 bowling green <unk> football team consists of 95 total players .
# gold tag is: o o i-org i-org i-org o o o o o o o o
# prediction : o o o i-per o o o o o o o o o
# score is: 118.02984104765774
# ====================================================
# sentence is: the class breakdown of these players is 12 <unk> , 21 <unk> , 30 <unk> , 12 <unk> <unk> , and 18 true <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o i-misc i-misc o o o o o o
# score is: 226.34931730985107
# ====================================================
# sentence is: returning <unk> from the 2006 team are six offensive <unk> and eight defensive <unk> .
# gold tag is: o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o
# score is: 128.86927136436768
# ====================================================
# sentence is: overall , 53 <unk> are returning from the 2006 team ( 25 on <unk> , 28 on defense and 0 on special teams ) .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 264.39347254719326
# ====================================================
# sentence is: as the 2007 college football season <unk> the end , many organizations began to <unk> <unk> and winners of various <unk> awards .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o
# score is: 220.36141196608466
# ====================================================
# sentence is: <unk> <unk> was named a <unk> for the <unk> trophy , given to the nation 's best center .
# gold tag is: i-per i-per o o o o o o i-misc i-misc o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o
# score is: 175.14566874690647
# ====================================================
# sentence is: he was one of 6 athletes recognized .
# gold tag is: o o o o o o o o
# prediction : o o o o o o o o
# score is: 80.57207655384586
# ====================================================
# sentence is: bowling green also had eight players make the <unk> teams ( the fourth most of any school in the mac ) .
# gold tag is: i-org i-org o o o o o o i-org i-org o o o o o o o o o i-org o o
# prediction : o o o o o o o o o o o o o o o o o o o i-org o o
# score is: 221.07568451572672
# ====================================================
# sentence is: 30 seconds to mars ( or thirty seconds to mars ) is an alternative rock band from los angeles , california , featuring jared leto , <unk> leto , <unk> <unk> .
# gold tag is: i-org i-org i-org i-org o o i-org i-org i-org i-org o o o o o o o i-loc i-loc o i-loc o o i-per i-per o i-per i-per o i-per i-per o
# prediction : o o o i-loc o o o o o i-loc o o o o o o o i-loc i-loc o i-loc o o i-per i-per o o i-per o o o o
# score is: 348.3862792992372
# ====================================================
# sentence is: created in 1998 by jared leto and his brother , <unk> , 30 seconds to mars began as a small family project .
# gold tag is: o o o o i-per i-per o o o o i-per o i-org i-org i-org i-org o o o o o o o
# prediction : o o o o i-per i-per o o o o o o o o o i-loc o o o o o o o
# score is: 254.43583415914338
# ====================================================
# sentence is: things began to speed up quickly , and matt <unk> later joined the band as <unk> and keyboard player .
# gold tag is: o o o o o o o o i-per i-per o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o i-misc o i-misc o o
# score is: 201.25497559240594
# ====================================================
# sentence is: after working with small <unk> door of <unk> ( as the band 's first two <unk> , kevin drake and <unk> <unk> , left the band due to issues primarily related to touring ) , the three <unk> <unk> <unk> to round out the band 's roster .
# gold tag is: o o o o o o o o o o o o o o o o o i-per i-per o i-per i-per o o o o o o o o o o o o o o o o i-per i-per o o o o o o o o
# prediction : o o o o i-misc i-misc o o o o o o o o o o o i-per i-per o i-misc i-misc o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 433.14326228937153
# ====================================================
# sentence is: according to an interview from virgin records , the band 's name
# gold tag is: o o o o o i-org i-org o o o o o
# prediction : o o o o o o o o o o o o
# score is: 106.33759036666724
# ====================================================
# sentence is: 30 seconds to mars ' first , <unk> album , produced by bob <unk> , was released in 2002 to mixed reviews and achieved sales of just over 100,000 .
# gold tag is: i-org i-org i-org i-org o o o o o o o o i-per i-per o o o o o o o o o o o o o o o o
# prediction : o o o i-loc o o o o o o o o i-per i-per o o o o o o o o o o o o o o o o
# score is: 309.71435221185277
# ====================================================
# sentence is: their <unk> album , a beautiful lie , was released on august 30 , 2005 .
# gold tag is: o o o o i-misc i-misc i-misc o o o o o o o o o
# prediction : o o o o i-misc i-misc o o o o o o o o o o
# score is: 154.98649568172468
# ====================================================
# sentence is: for this effort , the band traveled ( during the course of three years ) to four continents , to perfect their sound and also to allow for jared 's film career .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o o i-per o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o i-per o o o o
# score is: 368.419151463846
# ====================================================
# sentence is: the album was produced by <unk> abraham , whose producing credits also include <unk> , velvet <unk> , and <unk> park .
# gold tag is: o o o o o i-per i-per o o o o o o i-org o i-org i-org o o i-org i-org o
# prediction : o o o o o i-per i-per o o o o o o o o i-org i-org o o i-misc i-misc o
# score is: 206.57713875598483
# ====================================================
# sentence is: because a beautiful lie was <unk> five months before its release , the band decided to include two bonus tracks : " battle of one " ( an original song that was also set to be the album 's title track when it was first announced ) and " hunter " ( a cover of the <unk> song ) .
# gold tag is: o i-misc i-misc i-misc o o o o o o o o o o o o o o o o o o i-misc i-misc i-misc o o o o o o o o o o o o o o o o o o o o o o o o i-misc o o o o o o i-org o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o i-misc o o o o o o o o o o o o o o o o o o o o o o o o i-per o o o o o o o o o o
# score is: 611.2016621574354
# ====================================================
# sentence is: to further promote the album , the band also enclosed " golden tickets " in 12 copies , which granted their owners access to any 30 seconds to mars concert free of charge , along with <unk> access .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o i-org i-org i-org i-org o o o o o o o o o o
# prediction : o o o o o o o o o i-misc o i-misc i-misc o o i-misc o o o o o o o o o o o o i-loc o o o o o o o o o o
# score is: 383.13808874222724
# ====================================================
# sentence is: on august 31 , 2006 , the band won the <unk> award for " the kill " at the mtv video music awards , one of their two nominations .
# gold tag is: o o o o o o o o o o i-misc i-misc o o i-misc i-misc o o o i-misc i-misc i-misc i-misc o o o o o o o
# prediction : o o o o o o o o o o i-misc i-misc o o o o o o o i-misc o o o o o o o o o o
# score is: 291.2398840576885
# ====================================================
# sentence is: the second nomination was for best rock video ; however , they lost to afi 's " miss murder " .
# gold tag is: o o o o o o o o o o o o o o i-org o o i-misc i-misc o o
# prediction : o o o o o o o o o o o o o o i-per o o i-misc i-misc o o
# score is: 201.2281911924586
# ====================================================
# sentence is: in the video members of the band <unk> scenes from the shining .
# gold tag is: o o o o o o o o o o i-misc i-misc o
# prediction : o o o o o o o i-org i-org i-misc i-misc i-misc o
# score is: 110.80620770539012
# ====================================================
# sentence is: a beautiful lie was certified platinum by the riaa in january for distribution of over <unk> albums .
# gold tag is: i-misc i-misc i-misc o o o o o i-org o o o o o o o o o
# prediction : o o o o o o o o i-org o o o o o o o o o
# score is: 174.12987308976145
# ====================================================
# sentence is: in october , the band began their " welcome to the universe " tour , sponsored by <unk> .
# gold tag is: o o o o o o o o o o o o o o o o o i-org o
# prediction : o o o o o o o o o o o o o o o o o o o
# score is: 184.73408651538486
# ====================================================
# sentence is: they were supported on this tour by head <unk> , the receiving end of sirens , <unk> <unk> , and several other bands including street <unk> corps .
# gold tag is: o o o o o o o i-org i-org o i-org i-org i-org i-org i-org o i-org i-org o o o o o o i-org i-org i-org o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 282.2525566134362
# ====================================================
# sentence is: the tour was " environmentally sound " according to a 2006 interview with <unk> matt <unk> .
# gold tag is: o o o o o o o o o o o o o o i-per i-per o
# prediction : o o o o o o o o o o o o o o i-misc i-misc o
# score is: 146.26149027243463
# ====================================================
# sentence is: " jared and <unk> put together this thing called <unk> which is <unk> ways <unk> alternatives <unk> to kind of clean up some of the <unk> we leave behind .
# gold tag is: o i-per o i-per o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o i-per o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 310.3256933512774
# ====================================================
# sentence is: we fueled the bus with vegetable oil , " he explains .
# gold tag is: o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o
# score is: 130.17412295944067
# ====================================================
# sentence is: on november 20 , <unk> premiered the video for " from yesterday " ; the video is the first american rock video ever shot in its entirety in the people 's republic of china .
# gold tag is: o o o o i-org o o o o o i-misc i-misc o o o o o o o i-misc o o o o o o o o o i-loc i-loc i-loc i-loc i-loc o
# prediction : o o o o o o o o o o o i-misc o o o o o o o i-misc o o o o o o o o o i-loc i-loc i-loc i-loc i-loc o
# score is: 338.9154312283704
# ====================================================
# sentence is: the music video is loosely based on the film the last emperor .
# gold tag is: o o o o o o o o o i-misc i-misc i-misc o
# prediction : o o o o o o o o o o o o o
# score is: 110.0194369642894
# ====================================================
# sentence is: on april 29 , 2007 , the band performed at the australian mtv australia video music awards , where they were nominated for three awards , winning " best rock video " and " video of the year " for " the kill " .
# gold tag is: o o o o o o o o o o o i-misc i-misc i-misc i-misc i-misc i-misc o o o o o o o o o o o o o o o o o o o o o o o o i-misc i-misc o o
# prediction : o o o o o o o o o o o i-org i-org i-org o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 451.4059821666397
# ====================================================
# sentence is: as of spring 2007 , the band is supporting the used as a part of the " taste of chaos " tour and have scheduled a string of dates in europe supporting <unk> park .
# gold tag is: o o o o o o o o o i-org i-org o o o o o o o o o o o o o o o o o o o i-loc o i-org i-org o
# prediction : o o o o o o o o o o o o o o o o o o o i-misc o o o o o o o o o o i-loc o i-loc i-loc o
# score is: 350.61951930218544
# ====================================================
# sentence is: they are also scheduled to play <unk> , rock am ring , <unk> , give it a name festival and download .
# gold tag is: o o o o o o i-misc o i-misc i-misc i-misc o i-misc o i-misc i-misc i-misc i-misc i-misc o i-misc o
# prediction : o o o o o o o o o i-per o o o o o o o o o o o o
# score is: 202.80360093872358
# ====================================================
# sentence is: following other <unk> , they will begin working on their third album .
# gold tag is: o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o
# score is: 119.09753287722275
# ====================================================
# sentence is: following the release of " from yesterday " as a single , the band posted a link on their <unk> <unk> to vote for the next single from a beautiful lie .
# gold tag is: o o o o o i-misc i-misc o o o o o o o o o o o o i-org o o o o o o o o i-misc i-misc i-misc o
# prediction : o o o o o o i-misc o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 303.258001321528
# ====================================================
# sentence is: the choices available were " a beautiful lie " , " the fantasy " , " savior " , and " the story " .
# gold tag is: o o o o o i-misc i-misc i-misc o o o i-misc i-misc o o o i-misc o o o o i-misc i-misc o o
# prediction : o o o o o o o o o o o o i-misc o o o o o o o o o o o o
# score is: 239.54647936638335
# ====================================================
# sentence is: another vote was done later between the top two songs , " a beautiful lie " and " the fantasy " .
# gold tag is: o o o o o o o o o o o o i-misc i-misc i-misc o o o i-misc i-misc o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o
# score is: 222.0848707540521
# ====================================================
# sentence is: on may 2 , 2007 , the band announced that " a beautiful lie " had won and would be the next single .
# gold tag is: o o o o o o o o o o o i-misc i-misc i-misc o o o o o o o o o o
# prediction : o o o o o o o o o o o i-misc i-misc o o o o o o o o o o o
# score is: 252.18715764956107
# ====================================================
# sentence is: on august 8th , 2007 , <unk> ! announced that 30 seconds to mars has been nominated for two categories of the <unk> !
# gold tag is: o o o o o o i-org i-org o o i-org i-org i-org i-org o o o o o o o o i-org i-org
# prediction : o o o o o o o o o o o o o i-misc o o o o o o o o o o
# score is: 240.66404859555868
# ====================================================
# sentence is: awards 2007 <unk> best international <unk> and best single <unk> the kill .
# gold tag is: o o o o o o o o o o i-misc i-misc o
# prediction : o o o i-misc i-misc o o o o o o o o
# score is: 105.20806266032736
# ====================================================
# sentence is: on august 24th , they had only won the award for ' best single , ' which was the kill .
# gold tag is: o o o o o o o o o o o o o o o o o o i-misc i-misc o
# prediction : o o o o o o o o o o o o o o o o o o o o o
# score is: 222.51258178506154
# ====================================================
# sentence is: the other award was lost to <unk> lake .
# gold tag is: o o o o o o i-org i-org o
# prediction : o o o o o o o o o
# score is: 70.6843101715791
# ====================================================
# sentence is: on november 1 , 2007 , the band won the mtv europe music award for " rock out " , one of the two <unk> they were nominated in .
# gold tag is: o o o o o o o o o o i-misc i-misc i-misc i-misc o o i-misc i-misc o o o o o o o o o o o o
# prediction : o o o o o o o o o o i-org i-org i-org i-misc o o o o o o o o o o o o o o o o
# score is: 277.1455401903011
# ====================================================
# sentence is: on december 21st , 2007 , 30 seconds to mars won <unk> 's best of 2007 award .
# gold tag is: o o o o o o i-org i-org i-org i-org o i-org o i-misc i-misc i-misc i-misc o
# prediction : o o o o o o o o o i-loc o o o o o o o o
# score is: 192.12326747830343
# ====================================================
# sentence is: they beat out <unk> and had <unk> over 7 million votes .
# gold tag is: o o o i-org o o o o o o o o
# prediction : o o o o o o o o o o o o
# score is: 130.921718746489
# ====================================================
# sentence is: 31 other bands and artists such as justin <unk> , gwen <unk> , <unk> park and <unk> <unk> were also included in the contest .
# gold tag is: o o o o o o o i-per i-per o i-per i-per o i-org i-org o i-org i-org o o o o o o o
# prediction : o o o o o o o i-per i-per o i-per o o o i-misc o o o o o o o o o o
# score is: 237.0325294975224
# ====================================================
# sentence is: the band 's phoenix logo ( which the band named " <unk> " ) bears the phrase " <unk> in <unk> " , the band 's motto .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o i-misc i-misc o o o o o o o o o o o o o o o o o o o o o o o
# score is: 263.1670517266647
# ====================================================
# sentence is: roughly translated from latin , this means " launch forth into the deep " ; but a more <unk> version would be " rocket in ( to ) high ( <unk> ) " .
# gold tag is: o o o i-misc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o i-misc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 355.8807348724547
# ====================================================
# sentence is: the logo was primarily used for promotion of the band 's debut , whereas for a beautiful lie , the new trinity logo was created consisting of three <unk> , along with the band 's name and motto .
# gold tag is: o o o o o o o o o o o o o o o i-misc i-misc i-misc o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o i-misc i-misc o o o i-misc i-misc i-misc o o o o o o o o o o o o o o o o
# score is: 387.14003078081913
# ====================================================
# sentence is: the <unk> is a publicity street team for the band 30 seconds to mars , which helps in bringing friends to the shows , <unk> local radio stations to request the band 's songs , putting up <unk> , <unk> to band forums or related <unk> boards online , and maintaining magazines or websites dedicated to the band .
# ...
# gold tag is: i-misc o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 410.5242520169954
# ====================================================
# sentence is: written by <unk> ( <unk> ) , edited by <unk> ( <unk> )
# gold tag is: o o i-per o o o o o o i-per o o o
# prediction : o o o o o o o o o o o o o
# score is: 121.47046864916489
# ====================================================
# sentence is: 1 .
# gold tag is: o o
# prediction : o o
# score is: 16.118881584964726
# ====================================================
# sentence is: some old songs ' hard mix is <unk> songs ( e.g. <unk> , <unk> the flow , <unk> <unk> , the rhythm , <unk> <unk> , and so on ... )
# gold tag is: o o o o o o o o o o o i-misc o i-misc i-misc i-misc o i-misc i-misc o i-misc i-misc o i-misc i-misc o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 290.0713794110634
# ====================================================
# sentence is: 2 .
# gold tag is: o o
# prediction : o o
# score is: 16.27155864413831
# ====================================================
# sentence is: ' let it go ' , ' do you remember ?
# gold tag is: o i-misc i-misc i-misc o o o i-misc i-misc i-misc i-misc
# prediction : o o o o o o o o o o o
# score is: 96.50146310650847
# ====================================================
# sentence is: ' , ' <unk> dream <unk> ' are just <unk> <unk> version .
# gold tag is: o o o i-misc i-misc i-misc o o o o o o o
# prediction : o o o o o o o o o i-misc i-misc o o
# score is: 95.44945598804037
# ====================================================
# sentence is: 3 .
# gold tag is: o o
# prediction : o o
# score is: 17.381545903049442
# ====================================================
# sentence is: ' freedom ' is disappeared after 1st tracks , because sampling sound problem .
# gold tag is: o i-misc o o o o i-misc i-misc o o o o o o
# prediction : o o o o o o o o o o o o o o
# score is: 142.98693906041618
# ====================================================
# sentence is: 4 .
# gold tag is: o o
# prediction : o o
# score is: 14.657973887287111
# ====================================================
# sentence is: ' bob ' , ' my honey ' are disappeared after 2nd <unk> , and ' for 3 weeks ' is disappeared after 4th <unk> ( copyright problem ) .
# gold tag is: o i-misc o o o i-misc i-misc o o o o i-misc i-misc o o o i-misc i-misc i-misc o o o o i-misc i-misc o o o o o
# prediction : o i-per o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 313.6955749812212
# ====================================================
# sentence is: 4 .
# gold tag is: o o
# prediction : o o
# score is: 14.657973887287111
# ====================================================
# sentence is: <unk> is composed by <unk> <unk> ( < <unk> carlos , carlos is singer ) .
# gold tag is: i-misc o o o i-org i-org o o o i-per o i-per o o o o
# prediction : o o o o o o o o o i-per o i-per o o o o
# score is: 155.89424039111668
# ====================================================
# sentence is: 5 .
# gold tag is: o o
# prediction : o o
# score is: 17.376922966800663
# ====================================================
# sentence is: same composer
# gold tag is: o o
# prediction : o o
# score is: 19.812829853855106
# ====================================================
# sentence is: 6 .
# gold tag is: o o
# prediction : o o
# score is: 17.441430928073856
# ====================================================
# sentence is: secret of songs ' name ( original name )
# gold tag is: o o o o o o o o o
# prediction : o o o o o o o o o
# score is: 79.25551507232068
# ====================================================
# sentence is: 7 .
# gold tag is: o o
# prediction : o o
# score is: 19.23373496707532
# ====================================================
# sentence is: songs just in <unk>
# gold tag is: o o o o
# prediction : o o o o
# score is: 22.973568756802052
# ====================================================
# sentence is: ( 1 ) 1st tracks / 1st <unk>
# gold tag is: o o o i-misc i-misc o i-misc i-misc
# prediction : o o o o o o o o
# score is: 73.76209520771549
# ====================================================
# sentence is: ( 2 ) 2nd <unk>
# gold tag is: o o o i-misc i-misc
# prediction : o o o o o
# score is: 40.21992140834877
# ====================================================
# sentence is: ( 3 ) 3rd <unk>
# gold tag is: o o o i-misc i-misc
# prediction : o o o o o
# score is: 50.39374714916298
# ====================================================
# sentence is: <unk> albums of <unk> <unk> were not produced .
# gold tag is: o o o i-misc i-misc o o o o
# prediction : o o o o o o o o o
# score is: 76.71421262977002
# ====================================================
# sentence is: on july 10 , 2007 <unk> won a patent <unk> suit against <unk> world .
# gold tag is: o o o o o i-org o o o o o o i-org i-org o
# prediction : o o o o o o o o o o o o i-org i-org o
# score is: 136.63176760151092
# ====================================================
# sentence is: <unk> had originally filed a lawsuit against <unk> world in 2001 over the issue , and it has long since believed that they settled out of court due to the continued release of the title .
# gold tag is: i-org o o o o o o i-org i-org o o o o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 388.6912449618115
# ====================================================
# sentence is: a korean judge 's ruling has ordered <unk> world to pay <unk> damages and stop production of the product completely .
# gold tag is: o i-misc o o o o o i-org i-org o o i-org o o o o o o o o o
# prediction : o i-misc o o o o o o o o o o o o o o o o o o o
# score is: 230.81239913586788
# ====================================================
# sentence is: <unk> in satisfaction to <unk> <unk> billion won .
# gold tag is: i-org o o o i-org o o o o
# prediction : o o o o o o o o o
# score is: 89.94060585257886
# ====================================================
# sentence is: the fairfax <unk> is a public bus service provided by fairfax county , virginia , and operated by <unk> transport under contract .
# gold tag is: o i-org i-org o o o o o o o i-loc i-loc o i-loc o o o o i-org i-org o o o
# prediction : o i-org i-org o o o o o o o i-org i-org o i-org o o o o o o o o o
# score is: 199.12358947127186
# ====================================================
# sentence is: the first buses rolled out in september 1985 as a <unk> alternative to the <unk> service of the regional washington metropolitan area transit authority .
# gold tag is: o o o o o o o o o o o o o o i-org o o o o i-org i-org i-org i-org i-org o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 221.64986192669457
# ====================================================
# sentence is: the original routes connected the southern part of the county ( near the mount <unk> estate ) to the <unk> <unk> station which borders alexandria .
# gold tag is: o o o o o o o o o o o o o i-loc i-loc i-loc o o o i-loc i-loc i-loc o o i-loc o
# prediction : o o o o o o o o o o o o o i-loc i-loc i-loc o o o o o o o o i-loc o
# score is: 272.82180265944766
# ====================================================
# sentence is: this area continues to be the core of the system , and is noted for the number of residents in the richmond highway area who use the service at all times of the day .
# gold tag is: o o o o o o o o o o o o o o o o o o o o o i-loc i-loc o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o i-loc i-loc i-loc o o o o o o o o o o o
# score is: 365.18193822063984
# ====================================================
# sentence is: the fairfax <unk> , or simply " the <unk> " , has since expanded to <unk> routes spanning much of the county .
# gold tag is: o i-org i-org o o o o o o o o o o o o o o o o o o o o
# prediction : o i-org i-org o o o o o o o o o o o o o o o o o o o o
# score is: 248.48055521784582
# ====================================================
# sentence is: in 1994 , the service was extended to the <unk> industrial areas of suburban <unk> and herndon , located between washington , d.c. and washington <unk> international airport .
# gold tag is: o o o o o o o o o o o o o o i-loc o i-loc o o o i-loc i-loc i-loc o i-org i-org i-org i-org o
# prediction : o o o o o o o o o o o o o o o o o o o o i-loc o i-loc o i-loc i-loc i-loc i-loc o
# score is: 307.1651049406025
# ====================================================
# sentence is: along state route <unk> ( the <unk> toll road ) , express buses carry commuters from free <unk> <unk> to the washington metro system .
# gold tag is: o i-loc i-loc i-loc o o i-loc i-loc i-loc o o o o o o o o o o o o i-loc i-loc o o
# prediction : o o o o o o o o o o o o o o o o o o o o o i-per o o o
# score is: 244.16536173035408
# ====================================================
# sentence is: <unk> are paid in cash ( exact change ) , paper bus transfer , or a <unk> weekly <unk> bus " flash " pass .
# gold tag is: o o o o o o o o o o o o o o o o i-org o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 279.30278121914455
# ====================================================
# sentence is: fairfax <unk> deployed <unk> readers on its buses in may 2007 , extending the use of this washington metro <unk> system to fairfax county .
# gold tag is: i-org i-org o i-org o o o o o o o o o o o o o i-loc i-loc o o o i-loc i-loc o
# prediction : i-org i-org o o o o o o o o o o o o o o o i-per o o o o i-org o o
# score is: 246.76015787558242
# ====================================================
# sentence is: base <unk> is usually <unk> , but can be as much as <unk> for express routes .
# gold tag is: o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o
# score is: 182.18934564214678
# ====================================================
# sentence is: with a <unk> transfer , <unk> are discounted to <unk> exact change from <unk> <unk> , and <unk> exact change for <unk> <unk> .
# gold tag is: o o i-loc o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 252.85023392839187
# ====================================================
# sentence is: senior citizens receive discounted <unk> ( either <unk> or <unk> ) on all buses , or free <unk> with a <unk> transfer .
# gold tag is: o o o o o o o o o o o o o o o o o o o o i-loc o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o
# score is: 237.585570253133
# ====================================================
# sentence is: children under age 5 and the disabled ride free on all routes .
# gold tag is: o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o
# score is: 114.56285489489242
# ====================================================
# sentence is: the following are the line numbers and names that make up the fairfax <unk> bus system .
# gold tag is: o o o o o o o o o o o o i-org i-org o o o
# prediction : o o o o o i-misc o o o o o o i-org o o o o
# score is: 165.82543955369997
# ====================================================
# sentence is: <unk> state university is a public university located in <unk> , west virginia ( population <unk> ) .
# gold tag is: i-org i-org i-org o o o o o o i-loc o i-loc i-loc o o o o o
# prediction : i-org i-org i-org o o o o o o o o i-loc i-loc o o o o o
# score is: 156.3188140660683
# ====================================================
# sentence is: <unk> state was founded in 1865 as west virginia normal school at <unk> and was dedicated to <unk> teachers .
# gold tag is: i-org i-org o o o o o i-org i-org i-org i-org o i-loc o o o o o o o
# prediction : o o o o o o o i-loc i-loc o o o i-org o o o o o o o
# score is: 175.4112831209046
# ====================================================
# sentence is: it was purchased by the state and became <unk> state normal school in 1867 .
# gold tag is: o o o o o o o o i-org i-org i-org i-org o o o
# prediction : o o o o o o o o o o o o o o o
# score is: 123.64841231361696
# ====================================================
# sentence is: it was renamed <unk> state teachers college in 1931 and <unk> state college in 1943 .
# gold tag is: o o o i-org i-org i-org i-org o o o i-org i-org i-org o o o
# prediction : o o o i-per o o o o o o o o o o o o
# score is: 129.92186144851067
# ====================================================
# sentence is: in 1974 , a community college component was founded .
# gold tag is: o o o o o o o o o o
# prediction : o o o o o o o o o o
# score is: 110.2580339435787
# ====================================================
# sentence is: this became independently <unk> as the <unk> state community and technical college in 2003 and was merged into the university in 2006 and was renamed <unk> community & technical college .
# gold tag is: o o o o o o i-org i-org i-org i-org i-org i-org o o o o o o o o o o o o o i-org i-org i-org i-org i-org o
# prediction : o o o o o o i-misc i-misc o o o o o o o o o o o o o o o o o i-org i-org i-org i-org i-org o
# score is: 277.6920304677329
# ====================================================
# sentence is: on april 7 , 2004 , governor bob <unk> signed <unk> allowing <unk> state college to change its name to <unk> state university .
# gold tag is: o o o o o o o i-per i-per o o o i-org i-org i-org o o o o o i-org i-org i-org o
# prediction : o o o o o o o i-per i-per o o o o o o o o o o o o o o o
# score is: 237.31320445240462
# ====================================================
# sentence is: <unk> of the university is about <unk> .
# gold tag is: o o o o o o o o
# prediction : o o o i-org o o o o
# score is: 68.48306276844713
# ====================================================
# sentence is: <unk> offers masters degrees in business , education , teaching , criminal justice and <unk> in addition to 90 baccalaureate and 50 associate degrees .
# gold tag is: i-org o o o o o o o o o o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o o o o o o o o o
# score is: 213.95527731861657
# ====================================================
# sentence is: <unk> has added a major in intelligence research & analysis within the past few years .
# gold tag is: i-org o o o o o o o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o
# score is: 160.93403488932748
# ====================================================
# sentence is: this major has been gaining recognition for <unk> and attracting the attention of the intelligence community .
# gold tag is: o o o o o o o i-org o o o o o o o o o
# prediction : o o o o o o o o o o o o o o o o o
# score is: 196.28451208692522
# ====================================================
# sentence is: the robert c. <unk> national aerospace education center located in nearby bridgeport , west virginia , offers multiple programs in aviation .
# gold tag is: o i-org i-org i-org i-org i-org i-org i-org o o o i-loc o i-loc i-loc o o o o o o o
# prediction : o i-per i-per i-misc i-misc i-misc i-misc o o o o i-loc o i-loc i-loc o o o o o o o
# score is: 211.3721942651937
# ====================================================
# sentence is: <unk> state 's athletic teams , known as the <unk> , compete in the west virginia <unk> athletic conference in <unk> division ii .
# gold tag is: i-org i-org o o o o o o o i-org o o o o i-org i-org i-org i-org i-org o i-org i-org i-org o
# prediction : o o o o o o o o o o o o o o i-org i-org i-org i-org i-org o i-org i-org i-org o
# score is: 178.0347049655941
# ====================================================
# sentence is: a list of works by justin <unk> .
# gold tag is: o o o o o i-per i-per o
# prediction : o o o o o i-per i-per o
# score is: 78.63799288245455
# ====================================================
# sentence is: <unk> <unk> <unk> is a russian singer .
# gold tag is: i-per i-per i-per o o i-misc o o
# prediction : o o o o o i-misc o o
# score is: 59.13939454361396
